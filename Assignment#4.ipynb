# %%
# 1. Make a calculator using Python with addition, subtraction, multiplication ,division and power.
num1 = float(input("Enter 1st Number : "))
num2 = float(input("Enter 2nd Number : "))
print()
print("Enter 1 for Addition")
print("Enter 2 for Subtraction")
print("Enter 3 for Multiplication")
print("Enter 4 for Division")
print("Enter 5 for Power")
print()
choice = float(input("Enter Your Choice: "))
print()
if choice==1:
    print(num1,"+",num2," = ", num1+num2)
elif choice==2:
    print(num1,"-",num2," = ", num1-num2)
elif choice==3:
    print(num1,"*",num2," = ", num1*num2)
elif choice==4:
    if num2!=0:
        print(num1,"/",num2," = ", num1/num2)
    else:
        print("Any number divide by zero is invalid")
elif choice==5:
    print(num1,"power",num2," = ", num1**num2)
else:
    print("Invalid Number")
# Out:
# Enter 1st Number : 30
# Enter 2nd Number : 20
#
# Enter 1 for Addition
# Enter 2 for Subtraction
# Enter 3 for Multiplication
# Enter 4 for Division
# Enter 5 for Power
#
# Enter Your Choice: 5
#
# 30.0 power 20.0  =  3.486784401e+29

# %%
# 2. Write a program to check if there is any numeric value in list using for loop.

list = ["a", "b", 1, "c", 2, "d", "e", 3, 4] 
for x in list: 
    if type(x) == int: 
        print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
# 3. Write a Python script to add a key to a dictionary.

dict = {1:'a', 2:'b', 3:'c', 4:'d', 5:'e'}
print("dictionary before", dict)
dict.update({6:'f'})
print("dictionary after adding a key", dict)
# Out:
# dictionary before {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}
# dictionary after adding a key {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e', 6: 'f'}

# %%
# 4. Write a Python program to sum all the numeric items in a dictionary.
def returnSum(dict):
     
     sum = 0
     for i in dict.keys():
            for j in dict.values():
                if type(i) or type(j)==int:
                    sum = sum + i
      
                    return sum

dict = {1:'a', 2:'b', 3:'c', 4:'d', 5:'e'}
print("Sum :", returnSum(dict))
# Out:
# Sum : 1

# %%
# 5. Write a program to identify duplicate values from list.
list = ['1','a','2','b','2','c','d','c','a']
for i in range(0,len(list)):
    for j in range(i+1, len(list)):
        if (list[i]==list[j]):
            print(list[j])
# Out:
# a
# 2
# c

# %%
# 6. Write a Python script to check if a given key already exists in a dictionary.
dic = {1:'a', 2:'b',3:'c'}
def given_key(x=input("Please Enter a key")):
    if x in dic:
        print(x,"Key is already exist")
    else:
        print(x,"Key is not exist in the dictionary")
given_key()
