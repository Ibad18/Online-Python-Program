# %%
print("starts with the name of Allah");
# Out:
# starts with the name of Allah

# %%
list=["ibad", "KB", 28, "Khan"];
print(list);
# Out:
# ['ibad', 'KB', 28, 'Khan']

# %%
number = int(input("Please Enter the Number  "));
if number <100 and number>0:
    print("You have enter the number 0 to 100");
if number <1000 and number>100:
    print("You have enter the number 100 to 1000");
if number <10000 and number>1000:
    print("You have enter the number 1000 to 10000");
if number <100000 and number>10000:
    print("You have enter the number 100000 to 1000000");
if number <1000000 and number>100000:
    print("You have enter the number 1000000 to 10000000");
if number <10000000 and number>1000000:
    print("You have enter the number 10000000 to 100000000");
else:
    print("you have entered the number beyond the limit or it may have a string");
# Out:
# Please Enter the Number  3636363
# You have enter the number 10000000 to 100000000
